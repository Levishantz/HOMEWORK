# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import glob
import logging
import logging.handlers
import pprint

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient coun
cities_dataframe = pd.DataFrame(cities)
cities_dataframe.head()
# Out:
#             0
# 0       vaini
# 1     rikitea
# 2  vila velha
# 3   devonport
# 4   mahebourg

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#getting current weather for each city
# url to help with loggining 'https://docs.python.org/2.6/library/logging.html'
cities_dataframe_w = pd.DataFrame()
params = {
    "appid": api_key
}

counter_1 = 0
counter_2 = 0

weather_vara = []
for city in cities:
    
    base_url = 'http://api.openweathermap.org/data/2.5/weather'
    call_url = f'{base_url}'
    params['q'] = city
    weather_vara = requests.get(call_url, params=params).json()
    #pprint.pprint(weather_vara)
 
    try:
        cities_dataframe_w.loc[city, 'Cloudiness'] = weather_vara['clouds']['all']
        
        cities_dataframe_w.loc[city,'Country'] = weather_vara['sys']['country']
        cities_dataframe_w.loc[city,'Date'] = weather_vara['dt']
        cities_dataframe_w.loc[city,'Humidity'] = weather_vara['main']['humidity']
        cities_dataframe_w.loc[city,'Lat'] = weather_vara['coord']['lat']
        cities_dataframe_w.loc[city,'Lng'] = weather_vara['coord']['lon']
        cities_dataframe_w.loc[city,'Max Temp'] = weather_vara['main']['temp_max']
        cities_dataframe_w.loc[city,'Wind Speed'] = weather_vara['wind']['speed']
        cities_dataframe_w.loc[city,'Found'] = 'true' 
        print(f'Processing Record {counter_1} of set {counter_2} | {city}')
        if counter_1 < 50:
            counter_1 += 1
        else:
            counter_1 = 0
            counter_2 += 0
            
            
    except:
        cities_dataframe_w.loc[city,'Found'] = 'false'
        print('City not found, Skipping...')
# Out:
# Processing Record 0 of set 0 | vaini
# Processing Record 1 of set 0 | rikitea
# Processing Record 2 of set 0 | vila velha
# Processing Record 3 of set 0 | devonport
# Processing Record 4 of set 0 | mahebourg
# Processing Record 5 of set 0 | saint-philippe
# Processing Record 6 of set 0 | la ronge
# Processing Record 7 of set 0 | belle fourche
# City not found, Skipping...
# Processing Record 8 of set 0 | lazarev
# City not found, Skipping...
# Processing Record 9 of set 0 | tuktoyaktuk
# Processing Record 10 of set 0 | saskylakh
# Processing Record 11 of set 0 | chokurdakh
# Processing Record 12 of set 0 | roald
# Processing Record 13 of set 0 | east london
# Processing Record 14 of set 0 | saint george
# Processing Record 15 of set 0 | hobart
# City not found, Skipping...
# Processing Record 16 of set 0 | beringovskiy
# Processing Record 17 of set 0 | bima
# Processing Record 18 of set 0 | flinders
# Processing Record 19 of set 0 | namatanai
# Processing Record 20 of set 0 | carnarvon
# Processing Record 21 of set 0 | hasaki
# Processing Record 22 of set 0 | cape town
# Processing Record 23 of set 0 | shrewsbury
# Processing Record 24 of set 0 | punta arenas
# City not found, Skipping...
# Processing Record 25 of set 0 | hilo
# Processing Record 26 of set 0 | cururupu
# Processing Record 27 of set 0 | oktyabrskiy
# Processing Record 28 of set 0 | ust-tsilma
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 29 of set 0 | georgetown
# Processing Record 30 of set 0 | hermanus
# Processing Record 31 of set 0 | busselton
# Processing Record 32 of set 0 | kavaratti
# Processing Record 33 of set 0 | asbe teferi
# Processing Record 34 of set 0 | dikson
# Processing Record 35 of set 0 | thompson
# Processing Record 36 of set 0 | baghdad
# Processing Record 37 of set 0 | namibe
# Processing Record 38 of set 0 | bluff
# Processing Record 39 of set 0 | pahrump
# Processing Record 40 of set 0 | new norfolk
# Processing Record 41 of set 0 | lyuban
# Processing Record 42 of set 0 | kapaa
# Processing Record 43 of set 0 | lompoc
# Processing Record 44 of set 0 | norman wells
# City not found, Skipping...
# Processing Record 45 of set 0 | te anau
# Processing Record 46 of set 0 | khatanga
# Processing Record 47 of set 0 | vardo
# Processing Record 48 of set 0 | gweru
# Processing Record 49 of set 0 | choya
# Processing Record 50 of set 0 | caravelas
# Processing Record 0 of set 0 | evensk
# Processing Record 1 of set 0 | poronaysk
# Processing Record 2 of set 0 | ambon
# City not found, Skipping...
# Processing Record 3 of set 0 | yerbogachen
# Processing Record 4 of set 0 | cidreira
# Processing Record 5 of set 0 | krasnoufimsk
# Processing Record 6 of set 0 | kolosovka
# Processing Record 7 of set 0 | ancud
# Processing Record 8 of set 0 | salalah
# Processing Record 9 of set 0 | ixtapa
# Processing Record 10 of set 0 | tafresh
# Processing Record 11 of set 0 | atambua
# Processing Record 12 of set 0 | dukat
# City not found, Skipping...
# Processing Record 13 of set 0 | albany
# Processing Record 14 of set 0 | bredasdorp
# Processing Record 15 of set 0 | thinadhoo
# Processing Record 16 of set 0 | port macquarie
# Processing Record 17 of set 0 | coria
# Processing Record 18 of set 0 | grong
# Processing Record 19 of set 0 | rocha
# Processing Record 20 of set 0 | kahului
# Processing Record 21 of set 0 | katete
# Processing Record 22 of set 0 | esperance
# Processing Record 23 of set 0 | oussouye
# Processing Record 24 of set 0 | hun
# Processing Record 25 of set 0 | cabo san lucas
# Processing Record 26 of set 0 | marion
# Processing Record 27 of set 0 | puerto escondido
# Processing Record 28 of set 0 | mar del plata
# Processing Record 29 of set 0 | sitka
# Processing Record 30 of set 0 | iqaluit
# Processing Record 31 of set 0 | hithadhoo
# Processing Record 32 of set 0 | avarua
# Processing Record 33 of set 0 | panalingaan
# Processing Record 34 of set 0 | port alfred
# Processing Record 35 of set 0 | dangriga
# Processing Record 36 of set 0 | sattenapalle
# Processing Record 37 of set 0 | bloemfontein
# Processing Record 38 of set 0 | ushuaia
# Processing Record 39 of set 0 | castro
# Processing Record 40 of set 0 | hobyo
# City not found, Skipping...
# Processing Record 41 of set 0 | aklavik
# Processing Record 42 of set 0 | lorengau
# Processing Record 43 of set 0 | luderitz
# Processing Record 44 of set 0 | kavieng
# Processing Record 45 of set 0 | severo-kurilsk
# Processing Record 46 of set 0 | ambulu
# Processing Record 47 of set 0 | turukhansk
# Processing Record 48 of set 0 | leshukonskoye
# Processing Record 49 of set 0 | nanortalik
# Processing Record 50 of set 0 | uusikaupunki
# Processing Record 0 of set 0 | tabou
# City not found, Skipping...
# Processing Record 1 of set 0 | klaksvik
# City not found, Skipping...
# Processing Record 2 of set 0 | atuona
# City not found, Skipping...
# Processing Record 3 of set 0 | paamiut
# Processing Record 4 of set 0 | omboue
# Processing Record 5 of set 0 | zhigansk
# Processing Record 6 of set 0 | qaanaaq
# Processing Record 7 of set 0 | harper
# Processing Record 8 of set 0 | seydi
# Processing Record 9 of set 0 | chernyshevskiy
# Processing Record 10 of set 0 | kodiak
# Processing Record 11 of set 0 | kudahuvadhoo
# City not found, Skipping...
# Processing Record 12 of set 0 | ratnagiri
# City not found, Skipping...
# Processing Record 13 of set 0 | laguna
# Processing Record 14 of set 0 | mataura
# Processing Record 15 of set 0 | valparaiso
# Processing Record 16 of set 0 | alofi
# Processing Record 17 of set 0 | nanhai
# Processing Record 18 of set 0 | ewa beach
# Processing Record 19 of set 0 | westport
# Processing Record 20 of set 0 | guymon
# Processing Record 21 of set 0 | pisco
# City not found, Skipping...
# Processing Record 22 of set 0 | dhuburi
# Processing Record 23 of set 0 | pangnirtung
# Processing Record 24 of set 0 | butaritari
# Processing Record 25 of set 0 | pitelino
# Processing Record 26 of set 0 | tadine
# Processing Record 27 of set 0 | union
# Processing Record 28 of set 0 | puerto ayora
# Processing Record 29 of set 0 | port elizabeth
# Processing Record 30 of set 0 | bethel
# Processing Record 31 of set 0 | chuy
# Processing Record 32 of set 0 | teya
# Processing Record 33 of set 0 | arman
# Processing Record 34 of set 0 | kieta
# Processing Record 35 of set 0 | north platte
# Processing Record 36 of set 0 | talnakh
# Processing Record 37 of set 0 | bozoum
# Processing Record 38 of set 0 | adre
# Processing Record 39 of set 0 | teguldet
# Processing Record 40 of set 0 | margate
# Processing Record 41 of set 0 | new boston
# Processing Record 42 of set 0 | mawlaik
# City not found, Skipping...
# Processing Record 43 of set 0 | merauke
# Processing Record 44 of set 0 | monrovia
# Processing Record 45 of set 0 | carutapera
# Processing Record 46 of set 0 | lebu
# Processing Record 47 of set 0 | viedma
# City not found, Skipping...
# Processing Record 48 of set 0 | bathsheba
# Processing Record 49 of set 0 | provideniya
# Processing Record 50 of set 0 | havre-saint-pierre
# Processing Record 0 of set 0 | touros
# Processing Record 1 of set 0 | souillac
# Processing Record 2 of set 0 | moindou
# Processing Record 3 of set 0 | beian
# City not found, Skipping...
# Processing Record 4 of set 0 | halifax
# Processing Record 5 of set 0 | hirara
# Processing Record 6 of set 0 | mamallapuram
# Processing Record 7 of set 0 | akdepe
# Processing Record 8 of set 0 | straumen
# Processing Record 9 of set 0 | port said
# Processing Record 10 of set 0 | palmerston
# Processing Record 11 of set 0 | tiksi
# Processing Record 12 of set 0 | arraial do cabo
# Processing Record 13 of set 0 | methoni
# Processing Record 14 of set 0 | barrow
# Processing Record 15 of set 0 | yellowknife
# Processing Record 16 of set 0 | chebsara
# Processing Record 17 of set 0 | katsuura
# Processing Record 18 of set 0 | katobu
# Processing Record 19 of set 0 | baykit
# Processing Record 20 of set 0 | tasiilaq
# Processing Record 21 of set 0 | clyde river
# Processing Record 22 of set 0 | san patricio
# Processing Record 23 of set 0 | nassau
# Processing Record 24 of set 0 | okha
# Processing Record 25 of set 0 | bandarbeyla
# Processing Record 26 of set 0 | ulladulla
# Processing Record 27 of set 0 | ostrovnoy
# Processing Record 28 of set 0 | pasewalk
# Processing Record 29 of set 0 | ahipara
# Processing Record 30 of set 0 | bogorodskoye
# Processing Record 31 of set 0 | galesong
# Processing Record 32 of set 0 | torbay
# Processing Record 33 of set 0 | nkhotakota
# Processing Record 34 of set 0 | kizema
# Processing Record 35 of set 0 | rio gallegos
# Processing Record 36 of set 0 | dalvik
# Processing Record 37 of set 0 | kholtoson
# Processing Record 38 of set 0 | xapuri
# Processing Record 39 of set 0 | aketi
# City not found, Skipping...
# Processing Record 40 of set 0 | sola
# Processing Record 41 of set 0 | jamestown
# Processing Record 42 of set 0 | cherskiy
# Processing Record 43 of set 0 | kalagarh
# Processing Record 44 of set 0 | sao filipe
# Processing Record 45 of set 0 | vila franca do campo
# Processing Record 46 of set 0 | moerai
# Processing Record 47 of set 0 | tuatapere
# City not found, Skipping...
# Processing Record 48 of set 0 | golspie
# Processing Record 49 of set 0 | pringsewu
# Processing Record 50 of set 0 | moron
# Processing Record 0 of set 0 | jacareacanga
# Processing Record 1 of set 0 | victoria
# Processing Record 2 of set 0 | boa viagem
# Processing Record 3 of set 0 | sioux lookout
# City not found, Skipping...
# Processing Record 4 of set 0 | mattru
# Processing Record 5 of set 0 | chara
# Processing Record 6 of set 0 | viet tri
# Processing Record 7 of set 0 | thornaby
# Processing Record 8 of set 0 | upernavik
# Processing Record 9 of set 0 | buraydah
# Processing Record 10 of set 0 | juegang
# Processing Record 11 of set 0 | kloulklubed
# Processing Record 12 of set 0 | inhambane
# Processing Record 13 of set 0 | chekhov
# Processing Record 14 of set 0 | jiazi
# Processing Record 15 of set 0 | ozernovskiy
# Processing Record 16 of set 0 | riyadh
# Processing Record 17 of set 0 | rafai
# Processing Record 18 of set 0 | ribeira grande
# Processing Record 19 of set 0 | nurobod
# City not found, Skipping...
# Processing Record 20 of set 0 | muriwai beach
# Processing Record 21 of set 0 | vung tau
# City not found, Skipping...
# Processing Record 22 of set 0 | witu
# Processing Record 23 of set 0 | fairbanks
# Processing Record 24 of set 0 | cayenne
# Processing Record 25 of set 0 | port hardy
# Processing Record 26 of set 0 | hendersonville
# Processing Record 27 of set 0 | saint-jean-de-la-ruelle
# Processing Record 28 of set 0 | puri
# Processing Record 29 of set 0 | potam
# Processing Record 30 of set 0 | koshurnikovo
# Processing Record 31 of set 0 | hofn
# Processing Record 32 of set 0 | faanui
# Processing Record 33 of set 0 | tongzi
# Processing Record 34 of set 0 | sao joao da barra
# Processing Record 35 of set 0 | winslow
# Processing Record 36 of set 0 | hambantota
# Processing Record 37 of set 0 | antofagasta
# Processing Record 38 of set 0 | beira
# Processing Record 39 of set 0 | bonavista
# Processing Record 40 of set 0 | najran
# City not found, Skipping...
# Processing Record 41 of set 0 | tual
# Processing Record 42 of set 0 | hualmay
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 43 of set 0 | ponta do sol
# Processing Record 44 of set 0 | nouadhibou
# Processing Record 45 of set 0 | bonthe
# City not found, Skipping...
# Processing Record 46 of set 0 | onega
# Processing Record 47 of set 0 | fort nelson
# Processing Record 48 of set 0 | kolpashevo
# Processing Record 49 of set 0 | nikolskoye
# Processing Record 50 of set 0 | raudeberg
# Processing Record 0 of set 0 | karratha
# Processing Record 1 of set 0 | gallup
# Processing Record 2 of set 0 | tokonou
# Processing Record 3 of set 0 | kaitangata
# Processing Record 4 of set 0 | longyearbyen
# Processing Record 5 of set 0 | codrington
# Processing Record 6 of set 0 | walvis bay
# Processing Record 7 of set 0 | monastyrishche
# Processing Record 8 of set 0 | maniitsoq
# Processing Record 9 of set 0 | malpe
# Processing Record 10 of set 0 | wanaka
# Processing Record 11 of set 0 | mayumba
# Processing Record 12 of set 0 | brandon
# Processing Record 13 of set 0 | dunedin
# Processing Record 14 of set 0 | smithers
# Processing Record 15 of set 0 | maceio
# Processing Record 16 of set 0 | saint-pierre
# Processing Record 17 of set 0 | cockburn town
# Processing Record 18 of set 0 | tezu
# Processing Record 19 of set 0 | benavente
# Processing Record 20 of set 0 | coihaique
# Processing Record 21 of set 0 | talara
# Processing Record 22 of set 0 | masyaf
# City not found, Skipping...
# Processing Record 23 of set 0 | honningsvag
# Processing Record 24 of set 0 | shaunavon
# Processing Record 25 of set 0 | norden
# City not found, Skipping...
# Processing Record 26 of set 0 | kirensk
# Processing Record 27 of set 0 | humberto de campos
# Processing Record 28 of set 0 | grand gaube
# Processing Record 29 of set 0 | burns lake
# Processing Record 30 of set 0 | dzilam gonzalez
# Processing Record 31 of set 0 | mareeba
# Processing Record 32 of set 0 | tucuman
# Processing Record 33 of set 0 | alekseyevsk
# Processing Record 34 of set 0 | los llanos de aridane
# City not found, Skipping...
# Processing Record 35 of set 0 | leningradskiy
# Processing Record 36 of set 0 | marfino
# Processing Record 37 of set 0 | hamilton
# Processing Record 38 of set 0 | luba
# Processing Record 39 of set 0 | vestmannaeyjar
# Processing Record 40 of set 0 | phayuha khiri
# Processing Record 41 of set 0 | mangaratiba
# Processing Record 42 of set 0 | turayf
# Processing Record 43 of set 0 | sampit
# Processing Record 44 of set 0 | de-kastri
# Processing Record 45 of set 0 | bulgan
# Processing Record 46 of set 0 | charters towers
# Processing Record 47 of set 0 | mingshui
# Processing Record 48 of set 0 | lavrentiya
# City not found, Skipping...
# Processing Record 49 of set 0 | kalmunai
# Processing Record 50 of set 0 | havoysund
# City not found, Skipping...
# Processing Record 0 of set 0 | ugoofaaru
# Processing Record 1 of set 0 | nanakuli
# Processing Record 2 of set 0 | zeya
# Processing Record 3 of set 0 | aitape
# Processing Record 4 of set 0 | mount isa
# City not found, Skipping...
# Processing Record 5 of set 0 | khorramabad
# City not found, Skipping...
# Processing Record 6 of set 0 | samarai
# Processing Record 7 of set 0 | xinqing
# City not found, Skipping...
# Processing Record 8 of set 0 | fortuna
# Processing Record 9 of set 0 | lazaro cardenas
# Processing Record 10 of set 0 | kushiro
# City not found, Skipping...
# Processing Record 11 of set 0 | juba
# Processing Record 12 of set 0 | auki
# Processing Record 13 of set 0 | chazuta
# Processing Record 14 of set 0 | shepetivka
# Processing Record 15 of set 0 | ishigaki
# Processing Record 16 of set 0 | port-cartier
# Processing Record 17 of set 0 | mount pleasant
# Processing Record 18 of set 0 | fort frances
# Processing Record 19 of set 0 | port townsend
# Processing Record 20 of set 0 | mlonggo
# Processing Record 21 of set 0 | bongandanga
# Processing Record 22 of set 0 | guatire
# Processing Record 23 of set 0 | huarmey
# Processing Record 24 of set 0 | lakatoro
# Processing Record 25 of set 0 | la trinidad
# Processing Record 26 of set 0 | arlit
# Processing Record 27 of set 0 | araxa
# Processing Record 28 of set 0 | bambous virieux
# Processing Record 29 of set 0 | fare
# Processing Record 30 of set 0 | broome
# Processing Record 31 of set 0 | luan
# Processing Record 32 of set 0 | mielec
# Processing Record 33 of set 0 | masallatah
# Processing Record 34 of set 0 | ust-nera
# Processing Record 35 of set 0 | praia da vitoria
# Processing Record 36 of set 0 | eirunepe
# Processing Record 37 of set 0 | honghu
# Processing Record 38 of set 0 | stokmarknes
# Processing Record 39 of set 0 | nefteyugansk
# Processing Record 40 of set 0 | lensk
# Processing Record 41 of set 0 | sturgeon bay
# Processing Record 42 of set 0 | saint-louis
# Processing Record 43 of set 0 | kuressaare
# Processing Record 44 of set 0 | san cristobal
# Processing Record 45 of set 0 | lata
# Processing Record 46 of set 0 | boyolangu
# Processing Record 47 of set 0 | grindavik
# Processing Record 48 of set 0 | honiara
# Processing Record 49 of set 0 | danane
# Processing Record 50 of set 0 | palmer
# Processing Record 0 of set 0 | kysyl-syr
# Processing Record 1 of set 0 | rapid valley
# Processing Record 2 of set 0 | half moon bay
# Processing Record 3 of set 0 | zhuhai
# Processing Record 4 of set 0 | zimovniki
# Processing Record 5 of set 0 | san lorenzo
# Processing Record 6 of set 0 | keti bandar
# Processing Record 7 of set 0 | lakes entrance
# Processing Record 8 of set 0 | kyshtovka
# City not found, Skipping...
# Processing Record 9 of set 0 | banda aceh
# City not found, Skipping...
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 10 of set 0 | port hedland
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 11 of set 0 | conceicao do araguaia
# Processing Record 12 of set 0 | griffith
# Processing Record 13 of set 0 | spitak
# Processing Record 14 of set 0 | hashtrud
# City not found, Skipping...
# Processing Record 15 of set 0 | geraldton
# Processing Record 16 of set 0 | kijang
# Processing Record 17 of set 0 | saint-joseph
# Processing Record 18 of set 0 | premia de mar
# Processing Record 19 of set 0 | vieste
# Processing Record 20 of set 0 | george
# Processing Record 21 of set 0 | okato
# Processing Record 22 of set 0 | amboise
# Processing Record 23 of set 0 | ibra
# City not found, Skipping...
# Processing Record 24 of set 0 | srednekolymsk
# Processing Record 25 of set 0 | esso
# Processing Record 26 of set 0 | lakselv
# Processing Record 27 of set 0 | manzanillo
# Processing Record 28 of set 0 | egvekinot
# Processing Record 29 of set 0 | nchelenge
# Processing Record 30 of set 0 | takoradi
# Processing Record 31 of set 0 | praia
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 32 of set 0 | paracuru
# Processing Record 33 of set 0 | vila do maio
# Processing Record 34 of set 0 | wunsiedel
# Processing Record 35 of set 0 | pimentel
# Processing Record 36 of set 0 | rawson
# Processing Record 37 of set 0 | bangassou
# Processing Record 38 of set 0 | japura
# Processing Record 39 of set 0 | krasnoturansk
# Processing Record 40 of set 0 | key largo
# Processing Record 41 of set 0 | ahuimanu
# Processing Record 42 of set 0 | pinawa
# Processing Record 43 of set 0 | kantang
# Processing Record 44 of set 0 | narsaq
# Processing Record 45 of set 0 | road town
# City not found, Skipping...
# Processing Record 46 of set 0 | gumdag
# Processing Record 47 of set 0 | dana point
# City not found, Skipping...
# Processing Record 48 of set 0 | beloha
# Processing Record 49 of set 0 | manadhoo
# Processing Record 50 of set 0 | shu
# Processing Record 0 of set 0 | yulara
# Processing Record 1 of set 0 | ati
# Processing Record 2 of set 0 | pandamatenga
# Processing Record 3 of set 0 | arauco
# Processing Record 4 of set 0 | chapais
# Processing Record 5 of set 0 | north bend
# Processing Record 6 of set 0 | porkhov
# Processing Record 7 of set 0 | harrisonburg
# Processing Record 8 of set 0 | yumen
# Processing Record 9 of set 0 | constitucion
# City not found, Skipping...
# Processing Record 10 of set 0 | guarapari
# Processing Record 11 of set 0 | elko
# Processing Record 12 of set 0 | deputatskiy
# Processing Record 13 of set 0 | atar
# Processing Record 14 of set 0 | katherine
# Processing Record 15 of set 0 | crotone
# Processing Record 16 of set 0 | langsa
# Processing Record 17 of set 0 | axim
# Processing Record 18 of set 0 | avera
# Processing Record 19 of set 0 | shubarshi
# Processing Record 20 of set 0 | laguna de duero
# Processing Record 21 of set 0 | puerto carreno
# Processing Record 22 of set 0 | bilibino
# City not found, Skipping...
# Processing Record 23 of set 0 | dingalan
# Processing Record 24 of set 0 | pevek
# Processing Record 25 of set 0 | mandera
# Processing Record 26 of set 0 | casper
# City not found, Skipping...
# Processing Record 27 of set 0 | vostok
# Processing Record 28 of set 0 | bizhbulyak
# Processing Record 29 of set 0 | ulagan
# Processing Record 30 of set 0 | bani
# Processing Record 31 of set 0 | gunjur
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 32 of set 0 | kruisfontein
# Processing Record 33 of set 0 | talaya
# Processing Record 34 of set 0 | ribas do rio pardo
# City not found, Skipping...
# Processing Record 35 of set 0 | gidole
# Processing Record 36 of set 0 | sarana
# City not found, Skipping...
# Processing Record 37 of set 0 | dingle
# Processing Record 38 of set 0 | turbat
# Processing Record 39 of set 0 | ilulissat
# Processing Record 40 of set 0 | eyl
# Processing Record 41 of set 0 | sembakung
# Processing Record 42 of set 0 | pocri
# Processing Record 43 of set 0 | the valley
# Processing Record 44 of set 0 | manono
# Processing Record 45 of set 0 | yabrud
# Processing Record 46 of set 0 | port pirie
# Processing Record 47 of set 0 | marshall
# Processing Record 48 of set 0 | shahr-e kord
# City not found, Skipping...
# Processing Record 49 of set 0 | kuytun
# Processing Record 50 of set 0 | oudtshoorn
# Processing Record 0 of set 0 | pedernales
# Processing Record 1 of set 0 | pardina
# Processing Record 2 of set 0 | sorland
# Processing Record 3 of set 0 | alice springs
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 4 of set 0 | guerrero negro
# Processing Record 5 of set 0 | salinopolis
# Processing Record 6 of set 0 | mingyue
# Processing Record 7 of set 0 | nyagan
# Processing Record 8 of set 0 | ormara
# Processing Record 9 of set 0 | roma
# Processing Record 10 of set 0 | prince rupert
# Processing Record 11 of set 0 | tula
# Processing Record 12 of set 0 | ucluelet
# Processing Record 13 of set 0 | cap-aux-meules
# Processing Record 14 of set 0 | lodja
# Processing Record 15 of set 0 | lufilufi
# Processing Record 16 of set 0 | granollers
# Processing Record 17 of set 0 | rio grande
# Processing Record 18 of set 0 | lima
# City not found, Skipping...
# Processing Record 19 of set 0 | dutlwe
# Processing Record 20 of set 0 | magdagachi
# Processing Record 21 of set 0 | vanderhoof
# City not found, Skipping...
# Processing Record 22 of set 0 | along
# City not found, Skipping...
# Processing Record 23 of set 0 | majalaya
# Processing Record 24 of set 0 | vao
# Processing Record 25 of set 0 | champerico
# Processing Record 26 of set 0 | selma
# Processing Record 27 of set 0 | brae
# Processing Record 28 of set 0 | kyren
# Processing Record 29 of set 0 | mananjary
# Processing Record 30 of set 0 | kozhva
# Processing Record 31 of set 0 | montepuez
# Processing Record 32 of set 0 | obodivka
# Processing Record 33 of set 0 | concarneau
# City not found, Skipping...
# Processing Record 34 of set 0 | hailar
# Processing Record 35 of set 0 | carroll
# Processing Record 36 of set 0 | marawi
# City not found, Skipping...
# Processing Record 37 of set 0 | bougouni
# Processing Record 38 of set 0 | chifeng
# Processing Record 39 of set 0 | pastavy
# Processing Record 40 of set 0 | marsa matruh
# Processing Record 41 of set 0 | paraiso
# Processing Record 42 of set 0 | ouahigouya
# Processing Record 43 of set 0 | waipawa
# Processing Record 44 of set 0 | airai
# Processing Record 45 of set 0 | itarema
# Processing Record 46 of set 0 | tomatlan
# Processing Record 47 of set 0 | tupik
# Processing Record 48 of set 0 | aguimes
# Processing Record 49 of set 0 | bara
# Processing Record 50 of set 0 | buchanan
# Processing Record 0 of set 0 | alta floresta
# Processing Record 1 of set 0 | tigil
# Processing Record 2 of set 0 | san miguelito
# Processing Record 3 of set 0 | sao jose da coroa grande
# Processing Record 4 of set 0 | madimba
# Processing Record 5 of set 0 | rabo de peixe
# Processing Record 6 of set 0 | baiyin
# Processing Record 7 of set 0 | nome
# Processing Record 8 of set 0 | chutove
# Processing Record 9 of set 0 | san juan del cesar
# City not found, Skipping...
# Processing Record 10 of set 0 | veraval
# Processing Record 11 of set 0 | timiryazevskoye
# Processing Record 12 of set 0 | belmonte
# Processing Record 13 of set 0 | kavaje
# Processing Record 14 of set 0 | huron
# City not found, Skipping...
# Processing Record 15 of set 0 | birjand
# Processing Record 16 of set 0 | nisia floresta
# City not found, Skipping...
# Processing Record 17 of set 0 | sur
# City not found, Skipping...
# Processing Record 18 of set 0 | dwarka
# Processing Record 19 of set 0 | quatre cocos
# Processing Record 20 of set 0 | aykhal
# Processing Record 21 of set 0 | saldanha
# City not found, Skipping...
# Processing Record 22 of set 0 | pacifica
# Processing Record 23 of set 0 | batagay
# Processing Record 24 of set 0 | chingirlau
# Processing Record 25 of set 0 | milkovo
# Processing Record 26 of set 0 | port moresby
# Processing Record 27 of set 0 | sidi ali
# City not found, Skipping...
# City not found, Skipping...
# Processing Record 28 of set 0 | broken hill
# Processing Record 29 of set 0 | dong xoai
# Processing Record 30 of set 0 | natchez
# Processing Record 31 of set 0 | richards bay
# Processing Record 32 of set 0 | alta
# Processing Record 33 of set 0 | tiarei
# Processing Record 34 of set 0 | saquena
# City not found, Skipping...
# Processing Record 35 of set 0 | gazojak
# Processing Record 36 of set 0 | otukpo
# Processing Record 37 of set 0 | porec
# Processing Record 38 of set 0 | san quintin

# %%
#printing dataframe
cities_dataframe_w
# Out:
#                   Cloudiness Country          Date  Humidity    Lat     Lng  \
# vaini                   86.0      IN  1.563401e+09      90.0  15.34   74.49
# rikitea                 10.0      PF  1.563401e+09      72.0 -23.12 -134.97
# vila velha               0.0      BR  1.563401e+09      74.0  -3.71  -38.60
# devonport               11.0      AU  1.563401e+09      66.0 -41.18  146.36
# mahebourg               75.0      MU  1.563401e+09      68.0 -20.41   57.70
# saint-philippe           1.0      CA  1.563401e+09      78.0  45.36  -73.48
# la ronge                90.0      CA  1.563401e+09      53.0  55.10 -105.30
# belle fourche            1.0      US  1.563401e+09      50.0  44.67 -103.85
# samusu                   NaN     NaN           NaN       NaN    NaN     NaN
# lazarev                 50.0      RU  1.563401e+09      98.0  52.23  141.51
# illoqqortoormiut         NaN     NaN           NaN       NaN    NaN     NaN
# tuktoyaktuk             40.0      CA  1.563401e+09      82.0  69.44 -133.03
# saskylakh              100.0      RU  1.563401e+09      76.0  71.97  114.09
# chokurdakh             100.0      RU  1.563401e+09      83.0  70.62  147.90
# roald                    0.0      NO  1.563401e+09      93.0  62.58    6.12
# east london              0.0      ZA  1.563401e+09      61.0 -33.02   27.91
# saint george             0.0      GR  1.563401e+09      88.0  39.45   22.34
# hobart                  20.0      AU  1.563401e+09      98.0 -42.88  147.33
# yanchukan                NaN     NaN           NaN       NaN    NaN     NaN
# beringovskiy            89.0      RU  1.563401e+09      69.0  63.05  179.32
# bima                    95.0      ID  1.563401e+09      96.0  -8.45  118.73
# flinders                 0.0      AU  1.563401e+09      62.0 -34.58  150.85
# namatanai               59.0      PG  1.563401e+09      82.0  -3.66  152.44
# carnarvon               67.0      ZA  1.563401e+09      16.0 -30.97   22.13
# hasaki                  75.0      JP  1.563401e+09     100.0  35.73  140.83
# cape town               75.0      ZA  1.563401e+09      76.0 -33.93   18.42
# shrewsbury              90.0      US  1.563401e+09      88.0  39.77  -76.68
# punta arenas            20.0      CL  1.563401e+09      80.0 -53.16  -70.91
# nguiu                    NaN     NaN           NaN       NaN    NaN     NaN
# hilo                    90.0      US  1.563401e+09      83.0  19.71 -155.08
# ...                      ...     ...           ...       ...    ...     ...
# birjand                  0.0      IR  1.563401e+09      13.0  32.86   59.22
# nisia floresta          20.0      BR  1.563401e+09      78.0  -6.09  -35.21
# olafsvik                 NaN     NaN           NaN       NaN    NaN     NaN
# sur                     25.0      OM  1.563401e+09      62.0  22.57   59.53
# lolua                    NaN     NaN           NaN       NaN    NaN     NaN
# dwarka                  90.0      IN  1.563401e+09      94.0  28.58   77.04
# quatre cocos            75.0      MU  1.563401e+09      68.0 -20.21   57.76
# aykhal                   0.0      RU  1.563401e+09      75.0  65.95  111.51
# saldanha                 1.0      PT  1.563401e+09      53.0  41.42   -6.55
# maykain                  NaN     NaN           NaN       NaN    NaN     NaN
# pacifica                20.0      US  1.563401e+09      50.0  37.61 -122.49
# batagay                 78.0      RU  1.563401e+09      57.0  67.65  134.64
# chingirlau               0.0      KZ  1.563401e+09      76.0  51.09   54.08
# milkovo                 40.0      BG  1.563401e+09      56.0  41.53   24.68
# port moresby            40.0      PG  1.563401e+09      88.0  -9.47  147.16
# sidi ali                33.0      DZ  1.563401e+09      89.0  36.10    0.42
# rungata                  NaN     NaN           NaN       NaN    NaN     NaN
# kamenskoye               NaN     NaN           NaN       NaN    NaN     NaN
# broken hill              0.0      AU  1.563401e+09      93.0 -31.97  141.45
# dong xoai              100.0      VN  1.563401e+09      97.0  11.53  106.92
# natchez                  1.0      US  1.563401e+09      62.0  31.56  -91.40
# richards bay             0.0      ZA  1.563401e+09      46.0 -28.77   32.06
# alta                    75.0      NO  1.563401e+09      81.0  69.97   23.27
# tiarei                  20.0      PF  1.563401e+09      54.0 -17.53 -149.33
# saquena                 34.0      PE  1.563401e+09      68.0  -4.67  -73.52
# bolshoy uluy             NaN     NaN           NaN       NaN    NaN     NaN
# gazojak                  0.0      TM  1.563401e+09      11.0  41.19   61.40
# otukpo                  81.0      NG  1.563401e+09      91.0   7.19    8.13
# porec                  100.0      HR  1.563401e+09      72.0  45.23   13.59
# san quintin            100.0      PH  1.563401e+09      93.0  17.54  120.52
#
#                   Max Temp  Wind Speed  Found
# vaini              298.231        1.07   true
# rikitea            295.231        9.97   true
# vila velha         303.150        3.10   true
# devonport          280.930        0.89   true
# mahebourg          295.150        6.20   true
# saint-philippe     301.150        1.50   true
# la ronge           295.150        2.10   true
# belle fourche      301.480        3.10   true
# samusu                 NaN         NaN  false
# lazarev            285.331        9.68   true
# illoqqortoormiut       NaN         NaN  false
# tuktoyaktuk        288.150        6.20   true
# saskylakh          278.531        4.69   true
# chokurdakh         276.231        4.25   true
# roald              288.150        1.50   true
# east london        286.831        1.00   true
# saint george       292.150        1.31   true
# hobart             280.370        2.10   true
# yanchukan              NaN         NaN  false
# beringovskiy       289.931        1.80   true
# bima               291.631        0.89   true
# flinders           285.930        5.70   true
# namatanai          298.831        2.44   true
# carnarvon          282.931        2.35   true
# hasaki             295.370        1.50   true
# cape town          289.260        7.20   true
# shrewsbury         307.150        5.70   true
# punta arenas       275.150        3.10   true
# nguiu                  NaN         NaN  false
# hilo               299.820        2.60   true
# ...                    ...         ...    ...
# birjand            296.631        6.98   true
# nisia floresta     299.150        4.10   true
# olafsvik               NaN         NaN  false
# sur                301.131        5.87   true
# lolua                  NaN         NaN  false
# dwarka             303.150        2.10   true
# quatre cocos       295.150        6.20   true
# aykhal             279.150        3.00   true
# saldanha           295.631        3.11   true
# maykain                NaN         NaN  false
# pacifica           299.260        5.70   true
# batagay            280.231       11.38   true
# chingirlau         292.631        5.02   true
# milkovo            297.590        0.50   true
# port moresby       297.150        3.10   true
# sidi ali           296.731        6.95   true
# rungata                NaN         NaN  false
# kamenskoye             NaN         NaN  false
# broken hill        277.150        2.60   true
# dong xoai          296.931        2.05   true
# natchez            306.150        3.10   true
# richards bay       294.631        3.43   true
# alta               283.150        1.50   true
# tiarei             301.150        3.60   true
# saquena            302.131        1.62   true
# bolshoy uluy           NaN         NaN  false
# gazojak            306.031        4.71   true
# otukpo             297.431        1.44   true
# porec              297.150        3.60   true
# san quintin        297.531        5.65   true
#
# [621 rows x 9 columns]

# %%
cities_dataframe_w.to_html(bold)

# %%
#converting temp to celsius
cities_dataframe_cleaned = cities_dataframe_w.dropna()

temp_convert_celsius = cities_dataframe_cleaned['Max Temp'] - 273.15
temp_convert_celsius.head()
# Out:
# vaini         25.081
# rikitea       22.081
# vila velha    30.000
# devonport      7.780
# mahebourg     22.000
# Name: Max Temp, dtype: float64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#still working on it

cities_dataframe_cleaned.to_csv('file_name.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#becuse we live in canada, I used celsius. This isn't America
x_var1 = cities_dataframe_cleaned['Lat']
y_var1 = temp_convert_celsius

plt.title('City Latitude vs. Max Temp (14/22/19)')
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')

plt.grid(b=True, which='major', color='grey', linestyle='-')

plt.scatter(x_var1, y_var1, alpha=0.5, linewidths=1, edgecolors='black')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
y_var2 = cities_dataframe_cleaned['Humidity']

plt.title('City Lat vs. Humidity (14/22/19)')
plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.grid(b=True, which='major', color='grey', linestyle='-')

plt.scatter(x_var1,y_var2 , alpha=0.5)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
y_var3 = cities_dataframe_cleaned['Cloudiness']

plt.title('City Lat vs. Cludiness (14/22/19)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

plt.grid(b=True, which='major', color='grey', linestyle='-') 
plt.scatter(x_var1, y_var3 , alpha=0.5)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
y_var4 = cities_dataframe_cleaned['Wind Speed']

plt.title('City Lat vs. Wind Speed (14/22/19)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.grid(b=True, which='major', color='grey', linestyle='-')

plt.scatter(x_var1, y_var4 , alpha=0.5)
